# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\karmanya tyagi\Desktop\Data_sheet_1.csv')
df
# Out:
#             Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       BOPQ.S06AC000000000A  1971.06       426.0         NaN      F  Dollars
# 1       BOPQ.S06AC000000000A  1971.09       435.0         NaN      F  Dollars
# 2       BOPQ.S06AC000000000A  1971.12       360.0         NaN      F  Dollars
# 3       BOPQ.S06AC000000000A  1972.03       417.0         NaN      F  Dollars
# 4       BOPQ.S06AC000000000A  1972.06       528.0         NaN      F  Dollars
# ...                      ...      ...         ...         ...    ...      ...
# 176099  IIPA.S06ALDDDDPO7706  2015.03         NaN         NaN      C  Dollars
# 176100  IIPA.S06ALDDDDPO7706  2016.03         NaN         NaN      C  Dollars
# 176101  IIPA.S06ALDDDDPO7706  2017.03         NaN         NaN      C  Dollars
# 176102  IIPA.S06ALDDDDPO7706  2018.03         NaN         NaN      C  Dollars
# 176103  IIPA.S06ALDDDDPO7706  2019.03         NaN         NaN      C  Dollars
#
# ...

# %%
# %matplotlib inline
import numpy as np
df1 = df[['Period','Data_value']]
bins =  np.arange(0,5000,1000)
groups = df1.groupby(pd.cut(df1['Period'],bins)).mean()
print(groups.head())
groups['Period'].plot.line()
# Out:
#                    Period   Data_value
# Period
# (0, 1000]             NaN          NaN
# (1000, 2000]  1985.499066  1046.125971
# (2000, 3000]  2010.026198  6010.483298
# (3000, 4000]          NaN          NaN

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

X = df[['Period', 'MAGNTUDE']]
y = df['Data_value']

X[['Period', 'MAGNTUDE']] = scale.fit_transform(X[['Period', 'MAGNTUDE']])

print (X)

est = sm.OLS(y, X).fit()

est.summary()
# Out:
# C:\Users\karmanya tyagi\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\karmanya tyagi\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\karmanya tyagi\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
#           Period  MAGNTUDE
# ...

# %%
y.groupby(df.STATUS).mean()
# Out:
# STATUS
# C             NaN
# F     5039.042959
# R    21899.814995
# Name: Data_value, dtype: float64

# %%
scaled = scale.transform([[3000, 6]])
print(scaled)
predicted = est.predict(scaled[0])
print(predicted)
# Out:
# [[8.76869411e+01 6.79765288e-02]]
# [nan]
